# %% [markdown]
# # 深度學習計算性能優化完整指南 (2024-2025)
# :label:`chap_performance`
#
# 在深度學習中，數據集和模型通常都很大，導致計算量也會很大。
# 因此，計算的性能非常重要。
#
# 本章從**基礎到前沿**，全面涵蓋深度學習性能優化的方方面面：
# - **基礎篇**: 編譯器、異步計算、硬件基礎、多GPU訓練
# - **進階篇**: 混合精度、torch.compile、性能分析、記憶體優化
# - **前沿篇**: AI輔助優化、量化技術、分佈式訓練
#
# 通過學習本章，你可以：
# - ✓ 將訓練速度提升 2-10 倍
# - ✓ 減少 40-80% 記憶體使用
# - ✓ 掌握 2024-2025 最新優化技術
# - ✓ 學會使用 AI 輔助性能優化
#
# ## 📚 完整課程目錄
#
# ### 基礎篇 (D2L 原始內容)
# :begin_tab:toc
#  - [1_hybridize](1_hybridize.ipynb) - 編譯器與解釋器
#  - [2_async-computation](2_async-computation.ipynb) - 異步計算
#  - [3_auto-parallelism](3_auto-parallelism.ipynb) - 自動並行
#  - [4_hardware](4_hardware.ipynb) - 硬件基礎
#  - [5_multiple-gpus](5_multiple-gpus.ipynb) - 多 GPU 訓練
#  - [6_multiple-gpus-concise](6_multiple-gpus-concise.ipynb) - 多 GPU 簡潔版
#  - [7_parameterserver](7_parameterserver.ipynb) - 參數服務器
# :end_tab:
#
# ### 進階篇 (2024-2025 新增) ⭐
# :begin_tab:toc
#  - [8_mixed_precision_training](8_mixed_precision_training.ipynb) 🔥 - 混合精度訓練
#  - [9_profiling_tools](9_profiling_tools.ipynb) 🛠️ - 性能分析工具
#  - [10_torch_compile](10_torch_compile.ipynb) 🚀 - PyTorch 2.0 編譯優化
#  - [11_gpu_memory_optimization](11_gpu_memory_optimization.ipynb) 💾 - GPU 記憶體優化
#  - [14_ai_assisted_optimization](14_ai_assisted_optimization.ipynb) 🤖 - AI 輔助優化
# :end_tab:
#
# ## 🎯 快速開始
#
# 優先學習這些核心內容：
# 1. **8_mixed_precision_training** - 最大性能提升 (2-3x 加速)
# 2. **10_torch_compile** - PyTorch 2.0 核心特性
# 3. **9_profiling_tools** - 診斷性能瓶頸
# 4. **11_gpu_memory_optimization** - 解決 OOM 問題
#
# ## 📖 詳細學習指南
#
# 請參閱 [README.md](README.md) 獲取：
# - 完整學習路徑（入門→進階→精通）
# - 每個教程的詳細介紹
# - 實戰項目建議
# - AI 輔助學習技巧
# - 開發環境設置
# - 性能基準測試
#
# ## 🌟 最佳實踐模板
#
# ```python
# # 高性能訓練模板
# from torch.cuda.amp import autocast, GradScaler
#
# model = torch.compile(model)  # PyTorch 2.0+
# scaler = GradScaler()
#
# for data, target in dataloader:
#     optimizer.zero_grad()
#     with autocast():
#         output = model(data)
#         loss = criterion(output, target)
#     scaler.scale(loss).backward()
#     scaler.step(optimizer)
#     scaler.update()
# ```
#
# **版本**: v3.0 (2024-2025) | **更新**: 新增 5 個前沿教程
